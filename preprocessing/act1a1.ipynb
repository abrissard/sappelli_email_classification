# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('sappelli_data\sappelli_data.csv', sep=';')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alexi\AppData\Local\Temp\ipykernel_6244\2471882517.py:5: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv('sappelli_data\sappelli_data.csv', sep=';')

# %%
data.head()
# Out:
#       mid   Act1A1   Act1A2 Act2A1   Act2A2                    ReasA1  \
# 0  103944    greet    greet     {}       {}                  personal
# 1   33081  deliver  request     {}       {}  administrative procedure
# 2  103941  deliver  deliver     {}  propose                  personal
# 3  103860  deliver   remind     {}       {}  administrative procedure
# 4  321253   commit  deliver     {}       {}   employment arrangements
#
#                    ReasA2                    REA1             REA2 NumTA1  \
# 0                personal  accountable non-answer           ignore      0
# 1  internal collaboration  accountable non-answer  postponed reply      1
# 2                personal  accountable non-answer           ignore      0
# 3         legal procedure         immediate reply  immediate reply      1
# 4                personal         postponed reply           ignore      1
#
#    ... T3TyA1 T3TyA2 T3SubjA1  T3SubjA2                       sender  \
# ...

# %%
# Keep only NumTA1 column

act1a1 = data[['Act1A1', 'body']]
act1a1.head()
# Out:
#     Act1A1                                               body
# 0    greet  It was cute!\tGenia FitzGerald\t10/10/2000 03:...
# 1  deliver  Frankly, I don t remember it. Ask Linda.\tAndr...
# 2  deliver  It s really all Genia s fault, she goes to lun...
# 3  deliver  JustinI ve been running around trying to deter...
# 4   commit  Paul, I hope you feel better. I have seen the ...

# %%
act1a1.describe()
# Out:
#          Act1A1                                               body
# count      1144                                               1144
# unique        9                                               1063
# top     deliver  We have received an executed Fourth Amendment ...
# freq        498                                                  6

# %%
# remove rows with values not in "request", "propose", "commit", "deliver", "amend", "refuse", "greet", "remind"

act1a1 = act1a1[act1a1['Act1A1'].isin(['request', 'propose', 'commit', 'deliver', 'amend', 'refuse', 'greet', 'remind'])]
act1a1.describe()
# Out:
#          Act1A1                                               body
# count      1141                                               1141
# unique        8                                               1060
# top     deliver  We have received an executed Fourth Amendment ...
# freq        498                                                  6

# %%
# plot histogram of Act1A1

act1a1['Act1A1'].value_counts().plot(kind='bar')
plt.show()

# %%
# save to csv

act1a1.to_csv('sappelli_data\sappelli_data_act1a1.csv', index=False)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alexi\AppData\Local\Temp\ipykernel_6244\2328644165.py:3: SyntaxWarning: invalid escape sequence '\s'
#   act1a1.to_csv('sappelli_data\sappelli_data_act1a1.csv', index=False)
