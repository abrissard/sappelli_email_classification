# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('sappelli_data\sappelli_data.csv', sep=';')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alexi\AppData\Local\Temp\ipykernel_23476\2471882517.py:5: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv('sappelli_data\sappelli_data.csv', sep=';')
# C:\Users\alexi\AppData\Local\Temp\ipykernel_23476\2471882517.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data.head()
# Out:
#       mid   Act1A1   Act1A2 Act2A1   Act2A2                    ReasA1  \
# 0  103944    greet    greet     {}       {}                  personal
# 1   33081  deliver  request     {}       {}  administrative procedure
# 2  103941  deliver  deliver     {}  propose                  personal
# 3  103860  deliver   remind     {}       {}  administrative procedure
# 4  321253   commit  deliver     {}       {}   employment arrangements
#
#                    ReasA2                    REA1             REA2 NumTA1  \
# 0                personal  accountable non-answer           ignore      0
# 1  internal collaboration  accountable non-answer  postponed reply      1
# 2                personal  accountable non-answer           ignore      0
# 3         legal procedure         immediate reply  immediate reply      1
# 4                personal         postponed reply           ignore      1
#
#    ... T3TyA1 T3TyA2 T3SubjA1  T3SubjA2                       sender  \
# ...

# %%
# Keep only NumTA1 column

numta1 = data[['NumTA1', 'body']]
numta1.head()
# Out:
#   NumTA1                                               body
# 0      0  It was cute!\tGenia FitzGerald\t10/10/2000 03:...
# 1      1  Frankly, I don t remember it. Ask Linda.\tAndr...
# 2      0  It s really all Genia s fault, she goes to lun...
# 3      1  JustinI ve been running around trying to deter...
# 4      1  Paul, I hope you feel better. I have seen the ...

# %%
numta1.describe()
# Out:
#        NumTA1                                               body
# count    1144                                               1144
# unique     11                                               1063
# top         0  We have received an executed Fourth Amendment ...
# freq      563                                                  6

# %%
# remove rows with non numeric values in NumTA1

numta1 = numta1[numta1['NumTA1'].apply(lambda x: x.isnumeric())]
numta1.describe()
# Out:
#        NumTA1                                               body
# count    1139                                               1139
# unique      6                                               1060
# top         0  We have received an executed Fourth Amendment ...
# freq      563                                                  6

# %%
# plot histogram of NumTA1

numta1['NumTA1'] = numta1['NumTA1'].astype(int)
numta1['NumTA1'].plot.hist(bins=100)
plt.show()

# %%
# remove rows with 4 5 6

numta1 = numta1[numta1['NumTA1'] != 4]
numta1 = numta1[numta1['NumTA1'] != 5]
numta1 = numta1[numta1['NumTA1'] != 6]

numta1.describe()
# Out:
#             NumTA1
# count  1137.000000
# mean      0.559367
# std       0.612547
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       3.000000

# %%
# plot histogram of NumTA1

numta1['NumTA1'] = numta1['NumTA1'].astype(int)
numta1['NumTA1'].plot.hist(bins=100)
plt.show()

# %%
# save to csv

numta1.to_csv('sappelli_data\sappelli_data_numta1.csv', index=False)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alexi\AppData\Local\Temp\ipykernel_23476\3463623118.py:3: SyntaxWarning: invalid escape sequence '\s'
#   numta1.to_csv('sappelli_data\sappelli_data_numta1.csv', index=False)
